# %%
import numpy as np 
import pandas as pd 
import string 
import spacy 

from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
from wordcloud import WordCloud
# %matplotlib inline
from nltk.corpus import stopwords
from textblob import TextBlob
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data=pd.read_csv('/content/amzon review data.csv', encoding='cp1252')
data=data.iloc[:,0:50]
data.head(10)
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     18778586   RDIJS7QYB6XNR  B00EDBY7X8       122952789
# 1          US     24769659  R36ED1U38IELG8  B00D7JFOPC       952062646
# 2          US     44331596   R1UE3RPRGCOLD  B002LHA74O       818126353
# 3          US     23310293  R298788GS6I901  B00ARPLCGY       261944918
# 4          US     38745832    RNX4EXOBBPN5  B00UZOPOFW       717410439
# 5          US     13394189  R3BPETL222LMIM  B009B7F6CA       873028700
# 6          US      2749569  R3SORMPJZO3F2J  B0101EHRSM       723424342
# 7          US     41137196  R2RDOJQ0WBZCF6  B00407S11Y       383363775
# 8          US       433677  R2B8VBEPB4YEZ7  B00FGPU7U2       780517568
# 9          US      1297934  R1CB783I7B0U52  B0013OY0S0       269360126
#
#                                        product_title product_category  \
# 0                         Monopoly Junior Board Game             Toys
# 1  56 Pieces of Wooden Train Track Compatible wit...             Toys
# 2         Super Jumbo Playing Cards by S&S Worldwide             Toys
# 3           Barbie Doll and Fashions Barbie Gift Set             Toys
# 4  Emazing Lights eLite Flow Glow Sticks - Spinni...             Toys
# 5  Melissa & Doug Water Wow Coloring Book - Vehicles             Toys
# 6  Big Bang Cosmic Pegasus (Pegasis) Metal 4D Hig...             Toys
# 7         Fun Express Insect Finger Puppets 12ct Toy             Toys
# 8  Fisher-Price Octonauts Shellington's On-The-Go...             Toys
# 9           Claw Climber Goliath/ Disney's Gargoyles             Toys
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            5              0            0    N                 Y
# 1            5              0            0    N                 Y
# 2            2              1            1    N                 Y
# 3            5              0            0    N                 Y
# 4            1              1            1    N                 Y
# 5            5              0            0    N                 Y
# 6            3              2            2    N                 Y
# 7            5              0            0    N                 Y
# 8            5              0            0    N                 Y
# 9            1              0            1    N                 Y
#
#                                      review_headline  \
# 0                                         Five Stars
# 1              Good quality track at excellent price
# 2                                          Two Stars
# 3  my daughter loved it and i liked the price and...
# 4                                    DONT BUY THESE!
# 5                                         Five Stars
# 6                                        Three Stars
# 7                                         Five Stars
# 8                                         Five Stars
# 9                            Shame on the seller !!!
#
#                                          review_body review_date
# 0                                       Excellent!!!  31-08-2015
# 1  Great quality wooden track (better than some o...  31-08-2015
# 2                  Cards are not as big as pictured.  31-08-2015
# 3  my daughter loved it and i liked the price and...  31-08-2015
# 4  Do not buy these! They break very fast I spun ...  31-08-2015
# 5  Great item. Pictures pop thru and add detail a...  31-08-2015
# 6          To keep together, had to use crazy  glue.  31-08-2015
# 7                    I was pleased with the product.  31-08-2015
# 8                                   Children like it  31-08-2015
# 9  Showed up not how it's shown . Was someone's o...  31-08-2015

# %% [markdown]
# **Number Of words**

# %%
#Number of Words in single review
data['word_count'] = data['review_body'].apply(lambda x: len(str(x).split(" ")))
data[['review_body','word_count']].head()
# Out:
#                                          review_body  word_count
# 0                                       Excellent!!!           1
# 1  Great quality wooden track (better than some o...          45
# 2                  Cards are not as big as pictured.           7
# 3  my daughter loved it and i liked the price and...          31
# 4  Do not buy these! They break very fast I spun ...          49

# %% [markdown]
# **Number Of Char**

# %%
#Number of characters in single review including spaces
data['char_count'] = data['review_body'].str.len() 
data[['review_body','char_count']].head()
# Out:
#                                          review_body  char_count
# 0                                       Excellent!!!          12
# 1  Great quality wooden track (better than some o...         265
# 2                  Cards are not as big as pictured.          33
# 3  my daughter loved it and i liked the price and...         145
# 4  Do not buy these! They break very fast I spun ...         241

# %% [markdown]
# **Number of Stopwords**

# %%
stop = stopwords.words('english')

data['stopwords'] = data['review_body'].apply(lambda x: len([x for x in x.split() if x in stop]))
data[['review_body','stopwords']].head()
# Out:
#                                          review_body  stopwords
# 0                                       Excellent!!!          0
# 1  Great quality wooden track (better than some o...         17
# 2                  Cards are not as big as pictured.          4
# 3  my daughter loved it and i liked the price and...         16
# 4  Do not buy these! They break very fast I spun ...         21

# %%
# Total no.of stopwords in reviews
data['stopwords'].sum()
# Out:
# 584

# %% [markdown]
# **Data Pre-Processing**
#
# Converting to lower case

# %%
data['review_body'] = data['review_body'].apply(lambda x: " ".join(x.lower() for x in x.split()))
data['review_body'].head()
# Out:
# 0                                         excellent!!!
# 1    great quality wooden track (better than some o...
# 2                    cards are not as big as pictured.
# 3    my daughter loved it and i liked the price and...
# 4    do not buy these! they break very fast i spun ...
# Name: review_body, dtype: object

# %%
data['review_body'] = data['review_body'].str.replace('[^\w\s]','')
data['review_body'].head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# 0                                            excellent
# 1    great quality wooden track better than some ot...
# 2                     cards are not as big as pictured
# 3    my daughter loved it and i liked the price and...
# 4    do not buy these they break very fast i spun t...
# Name: review_body, dtype: object

# %% [markdown]
# Removing of Stop Words

# %%
stop = stopwords.words('english')
data['review_body'] = data['review_body'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
data['review_body'].head()
# Out:
# 0                                            excellent
# 1    great quality wooden track better others tried...
# 2                                   cards big pictured
# 3    daughter loved liked price came rather shoppin...
# 4    buy break fast spun 15 minutes end flew dont w...
# Name: review_body, dtype: object

# %% [markdown]
# **Tokenization**

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
review=np.array(data['review_body'])
s=str(review)
s
# Out:
# "['excellent'\n 'great quality wooden track better others tried perfect match various vintages thomas track already enough track fun get creative incorporating key pieces track splits loops bends'\n 'cards big pictured'\n 'daughter loved liked price came rather shopping ton people around amazon best way shop'\n 'buy break fast spun 15 minutes end flew dont waste money made cheap plastic cracks buy poi balls work lot better limited funds'\n 'great item pictures pop thru add detail 34painted34 pictures dry repainted'\n 'keep together use crazy glue' 'pleased product' 'children like'\n 'showed shown someones old toy paint'\n 'really liked little larger thought still fun'\n 'nice huge balloon local grocery store fill small fee totally worth'\n 'great deal' 'advertised'\n 'comes w 15 servo expect spend 150 good servo immediately stock one breaks right away'\n 'awesome thanks'\n 'got item son play around closest relevance items like army trained camera rc bots thing awesome tested range got somewhere close 50 yards without issue getting controls bit tricky first twenty minutes get feel drone comes fly ready sync controller definitely fan drones concern maybe little silent great buybr br disclaimer received product discount unbiased review'\n 'birthday present grandson loves'\n 'got wrong product amazon vine unable provide good review received pair cute girls gloves baseball ball instead expecting boys batting tee gloves cute however made least 6 yrs abovemore likely 89 yrs old girlsbr br cant provide fair review able use product'\n 'need expansion packs 35 want access player aids factions expansion base game alien frontiers plays much smoother adding factions expansion packs pigeonhole certain path victory'\n 'awesome customer service cool little drone especially price'\n 'got daughters plane trip liked zipper pouch attached markers however pouch fell girls loved coloring stickers would def buy'\n 'girlfriend yoga gave set yoga joes new home yoga room saw impressed found little green army men like brother used play realized yoga almost exploded delight seen look face needless say gift huge hit absolutely brilliant'\n 'like absoloutely hate dolls dont pets like one im stoked really would liked see pet'\n 'many wow toys home love well made advent calendar exception plastic thinner wow toys barn animals wont even stand due head weighing body uneven base toy disappointing love concept story read along everyday great would preferred quality would paid instead cheap 34knockoff34 rest toy line obvious weight toys sloppy paint jobs items 34wow toys34 bin part advent calendar vs rest toys also lot overlap wow town advent calendar winter wonderland calendar makes want look alternatives years advent calendar options'\n 'tons fun' 'love great add collecton'\n 'exactly described fits 7yr old well'\n 'purchased legos help aid teaching sunday school class children loved best part helped children remember past lessons true lego brand seem worksnap togetherfit together better generic brands plus lego snobs class would use real lego brand shunned generic brand wish legos little cheaper get pay would recommend quality purchase set'\n 'ok good old bite meez puppets puppet thin little yorkie often bites hands right stuffing durable enough really play'\n 'gift husband new pool receive color ordered one month use continuously mesh pulled away material inflatable side completely shredded longer use stored properly kept outside pool poorly made better going wm getting something clearance'\n 'ended sending guy back didnt need ive bought one past loved'\n 'product good box broken'\n 'works well quality product style board charge multiple batteries time safely batteries cell count battery composition lipo nimhetc must individual cell voltages close equal battery connected time board connected chargers read total individual cell voltage one batteries may charge others degree total rate charge divided equally batteries connected time close monitoring must using  ...

# %%
from nltk.tokenize import word_tokenize
text_tokens = word_tokenize(s)
print(text_tokens)
# Out:
# ['[', "'excellent'", "'great", 'quality', 'wooden', 'track', 'better', 'others', 'tried', 'perfect', 'match', 'various', 'vintages', 'thomas', 'track', 'already', 'enough', 'track', 'fun', 'get', 'creative', 'incorporating', 'key', 'pieces', 'track', 'splits', 'loops', "bends'", "'cards", 'big', "pictured'", "'daughter", 'loved', 'liked', 'price', 'came', 'rather', 'shopping', 'ton', 'people', 'around', 'amazon', 'best', 'way', "shop'", "'buy", 'break', 'fast', 'spun', '15', 'minutes', 'end', 'flew', 'dont', 'waste', 'money', 'made', 'cheap', 'plastic', 'cracks', 'buy', 'poi', 'balls', 'work', 'lot', 'better', 'limited', "funds'", "'great", 'item', 'pictures', 'pop', 'thru', 'add', 'detail', '34painted34', 'pictures', 'dry', "repainted'", "'keep", 'together', 'use', 'crazy', 'glue', "'", "'pleased", 'product', "'", "'children", "like'", "'showed", 'shown', 'someones', 'old', 'toy', "paint'", "'really", 'liked', 'little', 'larger', 'thought', 'still', "fun'", "'nice", 'huge', 'balloon', 'local', 'grocery', 'store', 'fill', 'small', 'fee', 'totally', "worth'", "'great", 'deal', "'", "'advertised'", "'comes", 'w', '15', 'servo', 'expect', 'spend', '150', 'good', 'servo', 'immediately', 'stock', 'one', 'breaks', 'right', "away'", "'awesome", "thanks'", "'got", 'item', 'son', 'play', 'around', 'closest', 'relevance', 'items', 'like', 'army', 'trained', 'camera', 'rc', 'bots', 'thing', 'awesome', 'tested', 'range', 'got', 'somewhere', 'close', '50', 'yards', 'without', 'issue', 'getting', 'controls', 'bit', 'tricky', 'first', 'twenty', 'minutes', 'get', 'feel', 'drone', 'comes', 'fly', 'ready', 'sync', 'controller', 'definitely', 'fan', 'drones', 'concern', 'maybe', 'little', 'silent', 'great', 'buybr', 'br', 'disclaimer', 'received', 'product', 'discount', 'unbiased', "review'", "'birthday", 'present', 'grandson', "loves'", "'got", 'wrong', 'product', 'amazon', 'vine', 'unable', 'provide', 'good', 'review', 'received', 'pair', 'cute', 'girls', 'gloves', 'baseball', 'ball', 'instead', 'expecting', 'boys', 'batting', 'tee', 'gloves', 'cute', 'however', 'made', 'least', '6', 'yrs', 'abovemore', 'likely', '89', 'yrs', 'old', 'girlsbr', 'br', 'cant', 'provide', 'fair', 'review', 'able', 'use', "product'", "'need", 'expansion', 'packs', '35', 'want', 'access', 'player', 'aids', 'factions', 'expansion', 'base', 'game', 'alien', 'frontiers', 'plays', 'much', 'smoother', 'adding', 'factions', 'expansion', 'packs', 'pigeonhole', 'certain', 'path', "victory'", "'awesome", 'customer', 'service', 'cool', 'little', 'drone', 'especially', "price'", "'got", 'daughters', 'plane', 'trip', 'liked', 'zipper', 'pouch', 'attached', 'markers', 'however', 'pouch', 'fell', 'girls', 'loved', 'coloring', 'stickers', 'would', 'def', "buy'", "'girlfriend", 'yoga', 'gave', 'set', 'yoga', 'joes', 'new', 'home', 'yoga', 'room', 'saw', 'impressed', 'found', 'little', 'green', 'army', 'men', 'like', 'brother', 'used', 'play', 'realized', 'yoga', 'almost', 'exploded', 'delight', 'seen', 'look', 'face', 'needless', 'say', 'gift', 'huge', 'hit', 'absolutely', "brilliant'", "'like", 'absoloutely', 'hate', 'dolls', 'dont', 'pets', 'like', 'one', 'im', 'stoked', 'really', 'would', 'liked', 'see', "pet'", "'many", 'wow', 'toys', 'home', 'love', 'well', 'made', 'advent', 'calendar', 'exception', 'plastic', 'thinner', 'wow', 'toys', 'barn', 'animals', 'wont', 'even', 'stand', 'due', 'head', 'weighing', 'body', 'uneven', 'base', 'toy', 'disappointing', 'love', 'concept', 'story', 'read', 'along', 'everyday', 'great', 'would', 'preferred', 'quality', 'would', 'paid', 'instead', 'cheap', '34knockoff34', 'rest', 'toy', 'line', 'obvious', 'weight', 'toys', 'sloppy', 'paint', 'jobs', 'items', '34wow', 'toys34', 'bin', 'part', 'advent', 'calendar', 'vs', 'rest', 'toys', 'also', 'lot', 'overlap', 'wow', 'town', 'advent', 'calendar', 'winter', 'wonderland', 'calendar', 'makes', 'want', 'look', 'alternatives', 'years', 'advent', 'calendar', "options'", "'tons", 'fun', "'", "'love", ' ...

# %% [markdown]
# **Lemmatization**

# %%
from textblob import Word

# %%
data['review_body'] = data['review_body'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data['review_body'].head()
# Out:
# 0                                            excellent
# 1    great quality wooden track better others tried...
# 2                                    card big pictured
# 3    daughter loved liked price came rather shoppin...
# 4    buy break fast spun 15 minute end flew dont wa...
# Name: review_body, dtype: object

# %% [markdown]
# **Sentiment Analysis**
#
# Sentiment Polarity

# %%
data['sentiment_polarity'] = data['review_body'].apply(lambda x: TextBlob(x).sentiment.polarity )
data[['review_body','sentiment_polarity']].head()
# Out:
#                                          review_body  sentiment_polarity
# 0                                          excellent            1.000000
# 1  great quality wooden track better others tried...            0.344444
# 2                                  card big pictured            0.000000
# 3  daughter loved liked price came rather shoppin...            0.766667
# 4  buy break fast spun 15 minute end flew dont wa...            0.165714

# %%
def getAnalysis(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'
data ['sentiment'] = data  ['sentiment_polarity'].apply(getAnalysis )
data[['review_body','sentiment','sentiment_polarity']]
# Out:
#                                           review_body sentiment  \
# 0                                           excellent  Positive
# 1   great quality wooden track better others tried...  Positive
# 2                                   card big pictured   Neutral
# 3   daughter loved liked price came rather shoppin...  Positive
# 4   buy break fast spun 15 minute end flew dont wa...  Positive
# 5   great item picture pop thru add detail 34paint...  Positive
# 6                        keep together use crazy glue  Negative
# 7                                     pleased product  Positive
# 8                                          child like   Neutral
# 9                  showed shown someone old toy paint  Positive
# 10       really liked little larger thought still fun  Positive
# 11  nice huge balloon local grocery store fill sma...  Positive
# 12                                         great deal  Positive
# 13                                         advertised   Neutral
# 14  come w 15 servo expect spend 150 good servo im...  Positive
# 15                                     awesome thanks  Positive
# 16  got item son play around closest relevance ite...  Positive
# 17                     birthday present grandson love  Positive
# 18  got wrong product amazon vine unable provide g...  Positive
# 19  need expansion pack 35 want access player aid ...  Negative
# 20  awesome customer service cool little drone esp...  Positive
# 21  got daughter plane trip liked zipper pouch att...  Positive
# 22  girlfriend yoga gave set yoga joes new home yo...  Positive
# 23  like absoloutely hate doll dont pet like one i...  Negative
# 24  many wow toy home love well made advent calend...  Positive
# 25                                            ton fun  Positive
# 26                           love great add collecton  Positive
# 27                 exactly described fit 7yr old well  Positive
# 28  purchased lego help aid teaching sunday school...  Positive
# 29  ok good old bite meez puppet puppet thin littl...  Positive
# 30  gift husband new pool receive color ordered on...  Positive
# 31  ended sending guy back didnt need ive bought o...  Positive
# 32                            product good box broken  Positive
# 33  work well quality product style board charge m...  Positive
# 34                                         great gift  Positive
# 35                         play game quite bit friend  Negative
# 36                              fit 20 bill perfectly  Positive
# 37  ordered 3 year old son birthday party party fa...  Positive
# 38  paper lantern adorable color bright pattern fu...  Positive
# 39                           grandson love card thank  Positive
# 40         received pineapple rather advertised smore   Neutral
# 41                                 christmas gift 6yr   Neutral
# 42                           grandson love card thank  Positive
# 43  even though kid top age recommendation level l...  Positive
# 44                                5 year old son love  Positive
# 45                                               love  Positive
# 46  absolutely one best trap game never dead alway...  Positive
# 47                                   really soft cute  Positive
# 48                         baby loved attractive nice  Positive
#
#     sentiment_polarity
# 0         1.000000e+00
# 1         3.444444e-01
# 2         0.000000e+00
# 3         7.666667e-01
# 4         1.657143e-01
# 5         3.666667e-01
# 6        -6.000000e-01
# 7         5.000000e-01
# 8         0.000000e+00
# 9         1.000000e-01
# 10        1.781250e-01
# 11        2.100000e-01
# 12        8.000000e-01
# 13        0.000000e+00
# 14        4.928571e-01
# 15        6.000000e-01
# 16        3.578125e-01
# 17        2.500000e-01
# 18        1.700000e-01
# 19       -2.071429e-01
# 20        2.906250e-01
# 21        6.500000e-01
# 22        3.414773e-01
# 23       -3.700743e-17
# 24        4.388889e-02
# 25        3.000000e-01
# 26        6.500000e-01
# 27        2.500000e-01
# 28        2.569444e-01
# 29        1.497768e-01
# 30        5.606061e-02
# 31        1.500000e-01
# 32        1.500000e-01
# 33        6.000000e-02
# 34        8.000000e-01
# 35       -4.000000e-01
# 36        7.000000e-01
# 37        4.000000e-01
# 38        4.618056e-01
# 39        5.000000e-01
# 40        0.000000e+00
# 41        0.000000e+00
# 42        5.000000e-01
# 43        1.833333e-01
# 44        3.000000e-01
# 45        5.000000e-01
# 46        1.480519e-01
# 47        3.000000e-01
# 48        7.000000e-01

# %%
# No.of Negative,Positive and Neutral Tweets in our given data

# %%
count=data['sentiment'].value_counts()
count
# Out:
# Positive    40
# Neutral      5
# Negative     4
# Name: sentiment, dtype: int64

# %%
data
# Out:
#    marketplace  customer_id       review_id  product_id  product_parent  \
# 0           US     18778586   RDIJS7QYB6XNR  B00EDBY7X8       122952789
# 1           US     24769659  R36ED1U38IELG8  B00D7JFOPC       952062646
# 2           US     44331596   R1UE3RPRGCOLD  B002LHA74O       818126353
# 3           US     23310293  R298788GS6I901  B00ARPLCGY       261944918
# 4           US     38745832    RNX4EXOBBPN5  B00UZOPOFW       717410439
# 5           US     13394189  R3BPETL222LMIM  B009B7F6CA       873028700
# 6           US      2749569  R3SORMPJZO3F2J  B0101EHRSM       723424342
# 7           US     41137196  R2RDOJQ0WBZCF6  B00407S11Y       383363775
# 8           US       433677  R2B8VBEPB4YEZ7  B00FGPU7U2       780517568
# 9           US      1297934  R1CB783I7B0U52  B0013OY0S0       269360126
# 10          US     52006292   R2D90RQQ3V8LH  B00519PJTW       493486387
# 11          US     32071052  R1Y4ZOUGFMJ327  B001TCY2DO       459122467
# 12          US      7360347  R2BUV9QJI2A00X  B00DOQCWF8       226984155
# 13          US     11613707   RSUHRJFJIRB3Z  B004C04I4I       375659886
# 14          US     13545982  R1T96CG98BBA15  B00NWGEKBY       933734136
# 15          US     43880421   R2ATXF4QQ30YW  B00000JS5S       341842639
# 16          US      1662075  R1YS3DS218NNMD  B00XPWXYDK       210135375
# 17          US     18461411  R2SDXLTLF92O0H  B00VPXX92W       705054378
# 18          US     27225859   R4R337CCDWLNG  B00YRA3H4U       223420727
# 19          US     20494593  R32Z6UA4S5Q630  B009T8BSQY       787701676
# 20          US      6762003  R1H1HOVB44808I  B00PXWS1CY       996611871
# 21          US     25402244   R4UVQIRZ5T1FM  1591749352       741582499
# 22          US     32910511  R226K8IJLRPTIR  B00V5DM3RE       587799706
# 23          US     18206299  R3031Q42BKAN7J  B00UMSVHD4       135383196
# 24          US     26599182   R44NP0QG6E98W  B00JLKI69W       375626298
# 25          US       128540  R24VKWVWUMV3M3  B004S8F7QM       829220659
# 26          US       125518  R2MW3TEBPWKENS  B00MZ6BR3Q       145562057
# 27          US     15048896  R3N01IESYEYW01  B001CTOC8O       278247652
# 28          US     12191231   RKLAK7EPEG5S6  B00BMKL5WY       906199996
# 29          US     18409006  R1HOJ5GOA2JWM0  B00L71H0F4       692305292
# 30          US     42523709   RO5VL1EAPX6O3  B004CLZRM4        59085350
# 31          US     45601416  R3OSJU70OIBWVE  B000PEOMC8       895316207
# 32          US     47546726  R3NFZZCJSROBT4  B008W1BPWQ       397107238
# 33          US     21448082   R47XBGQFP039N  B00FZX71BI       480992295
# 34          US     12612039  R1JS8G26X4RM2G  B00D4NJSJE       408940178
# 35          US     44928701  R1ORWPFQ9EDYA0  B000HZZT7W       967346376
# 36          US     43173394  R1YIX4SO32U0GT  B002G54DAA        57447684
# 37          US     11210951  R1W3QQZ8JKECCI  B003JT0L4Y       876626440
# 38          US     12918717    RZX17JIYIPAR  B00KQUNNZ8       644368246
# 39          US     47781982   RIDVQ4P3WJR42  B00WTGGGRO       162262449
# 40          US     34874898  R1WQ3ME3JAG2O1  B00WAKEQLW       824555589
# 41          US     20962528   RNTPOUDQIICBF  B00M5AT30G       548190970
# 42          US     47781982  R3AHZWWOL0IAV0  B00GNDY40U       438056479
# 43          US     13328687  R3PDXKS9O2Z20B  B00WJ1OPMW       120071056
# 44          US     16245463  R23URALWA7IHWL  B00IGXV9UI       765869385
# 45          US     11916403  R36L8VKT9ZSUY6  B00JVY9J1M       771795950
# 46          US      5543658  R23JRQR6VMY4TV  B008AL15M8       211944547
# 47          US     41168357  R3T73PQZZ9F6GT  B00CAEEDC0        72805974
# 48          US     32866903  R300I65NW30Y19  B000TFLAZA       149264874
#
#                                         product_title product_category  \
# 0                          Monopoly Junior Board Game             Toys
# 1   56 Pieces of Wooden Train Track Compatible wit...             Toys
# 2          Super Jumbo Playing Cards by S&S Worldwide             Toys
# 3            Barbie Doll and Fashions Barbie Gift Set             Toys
# 4   Emazing Lights eLite Flow Glow Sticks - Spinni...             Toys
# 5   Melissa & Doug Water Wow Coloring Book - Vehicles             Toys
# 6   Big Bang Cosmic Pegasus (Pegasis) Metal 4D Hig...             Toys
# 7          Fun Express Insect Finger Puppets 12ct Toy             Toys
# 8   Fisher-Price Octonauts Shellington's On-The-Go...             Toys
# 9            Claw Climber Goliath/ Disney's Gargoyles             Toys
# 10                 100 Foot Multicolor Pennant Banner             Toys
# 11                             Pig Jumbo Foil Balloon             Toys
# 12                      Minecraft Animal Toy (6-Pack)             Toys
# 13                    Disney Baby: Eeyore Large Plush             Toys
# 14  Team Losi 8IGHT-E RTR AVC Electric 4WD Buggy V...             Toys
# 15  Hot Wheels 48- Car storage Case With Easy Grip...             Toys
# 16  ZuZo 2.4GHz 4 CH 6 Axis Gyro RC Quadcopter Dro...             Toys
# 17  Teenage Mutant Ninja Turtles T-Machines Tiger ...             Toys
# 18          Franklin Sports MLB Fold Away Batting Tee             Toys
# 19                          Alien Frontiers: Factions             Toys
# 20  Holy Stone F180C Mini RC Quadcopter Drone with...             Toys
# 21  Klutz Sticker Design Studio: Create Your Own C...             Toys
# 22                    Yoga Joes - Green Army Men Toys             Toys
# 23  Lalaloopsy Girls Basic Doll- Prairie Dusty Trails             Toys
# 24                      WOW Toys Town Advent Calendar             Toys
# 25                             Cards Against Humanity             Toys
# 26  Monster High Haunted Student Spirits Porter Ge...             Toys
# 27  Star Wars Clone Wars Clone Trooper Child's Del...             Toys
# 28  LEGO Creative Tower Building Kit XXL 1600 Piec...             Toys
# 29          Barkology Princess the Poodle Hand Puppet             Toys
# 30                Intex Mesh Lounge (Colors May Vary)             Toys
# 31  Intex River Run I Sport Lounge, Inflatable Wat...             Toys
# 32  Peppa Pig 7 Wood Puzzles In Wooden Storage Box...             Toys
# 33  Paraboard - Parallel Charging Board for Lipos ...             Toys
# 34  The Game of Life Money and Asset Board Game, F...             Toys
# 35                          LCR Dice Game (Red Chips)             Toys
# 36  BCW - Deluxe Currency Slab - Regular Bill - Do...             Toys
# 37  Ocean Life Stamps Birthday Party Supplies Loot...             Toys
# 38  New Age Scare Halloween Party Pumpkin and Bat ...             Toys
# 39  Pokemon - Double Dragon Energy (97/108) - XY R...             Toys
# 40  Whiffer Sniffers Mystery Pack 1 Scented Backpa...             Toys
# 41                  AmiGami Fox and Owl Figure 2-Pack             Toys
# 42  Pokemon - Gyarados (31/113) - Legendary Treasures             Toys
# 43  LeapFrog LeapTV Letter Factory Adventures Educ...             Toys
# 44  Disney Planes: Fire & Rescue Scoop & Spray Fir...             Toys
# 45  Winston Zeddmore & Ecto-1: Funko POP! Rides x ...             Toys
# 46  Yu-Gi-Oh! - Solemn Judgment (GLD5-EN045) - Gol...             Toys
# 47                             Seat Pets Car Seat Toy             Toys
# 48                            Baby Einstein Octoplush             Toys
#
#     star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0             5              0            0    N                 Y
# 1             5              0            0    N                 Y
# 2             2              1            1    N                 Y
# 3             5              0            0    N                 Y
# 4             1              1            1    N                 Y
# 5             5              0            0    N                 Y
# 6             3              2            2    N                 Y
# 7             5              0            0    N                 Y
# 8             5              0            0    N                 Y
# 9             1              0            1    N                 Y
# 10            5              0            0    N                 Y
# 11            5              0            0    N                 Y
# 12            5              0            1    N                 Y
# 13            4              0            0    N                 Y
# 14            3              2            4    N                 Y
# 15            5              0            0    N                 Y
# 16            5              4            4    N                 N
# 17            5              0            0    N                 Y
# 18            3              0            1    Y                 N
# 19            1              0            0    N                 Y
# 20            5              1            1    N                 N
# 21            4              1            2    N                 Y
# 22            5              0            1    N                 Y
# 23            4              1            1    N                 N
# 24            3              1            1    N                 Y
# 25            5              0            0    N                 Y
# 26            5              0            0    N                 Y
# 27            5              0            1    N                 Y
# 28            5              1            2    N                 Y
# 29            2              1            1    N                 Y
# 30            1              0            0    N                 Y
# 31            5              0            0    N                 Y
# 32            3              0            0    N                 Y
# 33            5              0            0    N                 Y
# 34            5              0            1    N                 Y
# 35            5              0            0    N                 Y
# 36            5              0            1    N                 Y
# 37            5              0            0    N                 Y
# 38            5              0            0    N                 N
# 39            5              1            1    N                 Y
# 40            1              0            6    N                 Y
# 41            4              0            0    N                 Y
# 42            5              0            0    N                 Y
# 43            5              0            0    N                 N
# 44            5              0            0    N                 Y
# 45            5              0            0    N                 Y
# 46            5              0            0    N                 Y
# 47            5              0            0    N                 Y
# 48            5              0            0    N                 Y
#
#                                       review_headline  \
# 0                                          Five Stars
# 1               Good quality track at excellent price
# 2                                           Two Stars
# 3   my daughter loved it and i liked the price and...
# 4                                     DONT BUY THESE!
# 5                                          Five Stars
# 6                                         Three Stars
# 7                                          Five Stars
# 8                                          Five Stars
# 9                             Shame on the seller !!!
# 10                                         Five Stars
# 11                                  Nice huge balloon
# 12                                         Five Stars
# 13                                         Four Stars
# 14  ... servo so expect to spend 150 more on a goo...
# 15                                         Five Stars
# 16  The closest relevance I have to items like the...
# 17                                         Five Stars
# 18                  Got wrong product in the shipment
# 19                                        Overpriced.
# 20                                         Five Stars
# 21                    Great product for little girls!
# 22                                  Creative and fun!
# 23  i like it but i absoloutely hate that some dol...
# 24                     We love how well they are made
# 25                                         Five Stars
# 26                                         Five Stars
# 27                                         Five Stars
# 28  The children LOVED them and best part was that...
# 29  My little dog can bite my hand right through t...
# 30                       Save your money...don't buy!
# 31          but I've bought one in the past and loved
# 32                                        Three Stars
# 33       CAN SAVE TME IF YOU UNDESTAND HOW IT WORKS .
# 34                                         Five Stars
# 35                                         Five Stars
# 36                         BCW - Deluxe Currency Slab
# 37                       Fun for birthday party favor
# 38                                   Love the prints!
# 39                                         Five Stars
# 40                                           One Star
# 41                                         Four Stars
# 42                                         Five Stars
# 43                                they LOVE this game
# 44                                         Five Stars
# 45                                         Five Stars
# 46       Absolutely one of the best traps in the game
# 47                                         Five Stars
# 48                                         Five Stars
#
#                                           review_body review_date  word_count  \
# 0                                           excellent  31-08-2015           1
# 1   great quality wooden track better others tried...  31-08-2015          45
# 2                                   card big pictured  31-08-2015           7
# 3   daughter loved liked price came rather shoppin...  31-08-2015          31
# 4   buy break fast spun 15 minute end flew dont wa...  31-08-2015          49
# 5   great item picture pop thru add detail 34paint...  31-08-2015          18
# 6                        keep together use crazy glue  31-08-2015           9
# 7                                     pleased product  31-08-2015           6
# 8                                          child like  31-08-2015           3
# 9                  showed shown someone old toy paint  31-08-2015          15
# 10       really liked little larger thought still fun  31-08-2015          14
# 11  nice huge balloon local grocery store fill sma...  31-08-2015          21
# 12                                         great deal  31-08-2015           2
# 13                                         advertised  31-08-2015           2
# 14  come w 15 servo expect spend 150 good servo im...  31-08-2015          23
# 15                                     awesome thanks  31-08-2015           3
# 16  got item son play around closest relevance ite...  31-08-2015         125
# 17                     birthday present grandson love  31-08-2015          12
# 18  got wrong product amazon vine unable provide g...  31-08-2015          68
# 19  need expansion pack 35 want access player aid ...  31-08-2015          48
# 20  awesome customer service cool little drone esp...  31-08-2015          12
# 21  got daughter plane trip liked zipper pouch att...  31-08-2015          40
# 22  girlfriend yoga gave set yoga joes new home yo...  31-08-2015          81
# 23  like absoloutely hate doll dont pet like one i...  31-08-2015          30
# 24  many wow toy home love well made advent calend...  31-08-2015         167
# 25                                            ton fun  31-08-2015           3
# 26                           love great add collecton  31-08-2015           6
# 27                 exactly described fit 7yr old well  31-08-2015           9
# 28  purchased lego help aid teaching sunday school...  31-08-2015          89
# 29  ok good old bite meez puppet puppet thin littl...  31-08-2015          36
# 30  gift husband new pool receive color ordered on...  31-08-2015          75
# 31  ended sending guy back didnt need ive bought o...  31-08-2015          21
# 32                            product good box broken  31-08-2015           9
# 33  work well quality product style board charge m...  31-08-2015         173
# 34                                         great gift  31-08-2015           2
# 35                         play game quite bit friend  31-08-2015           9
# 36                              fit 20 bill perfectly  31-08-2015           5
# 37  ordered 3 year old son birthday party party fa...  31-08-2015          28
# 38  paper lantern adorable color bright pattern fu...  31-08-2015          96
# 39                           grandson love card thank  31-08-2015           8
# 40         received pineapple rather advertised smore  31-08-2015           8
# 41                                 christmas gift 6yr  31-08-2015           4
# 42                           grandson love card thank  31-08-2015           8
# 43  even though kid top age recommendation level l...  31-08-2015          80
# 44                                5 year old son love  31-08-2015           7
# 45                                               love  31-08-2015           2
# 46  absolutely one best trap game never dead alway...  31-08-2015          47
# 47                                   really soft cute  31-08-2015           4
# 48                         baby loved attractive nice  31-08-2015           9
#
#     char_count  stopwords  sentiment_polarity sentiment
# 0           12          0        1.000000e+00  Positive
# 1          265         17        3.444444e-01  Positive
# 2           33          4        0.000000e+00   Neutral
# 3          145         16        7.666667e-01  Positive
# 4          241         21        1.657143e-01  Positive
# 5          105          6        3.666667e-01  Positive
# 6           41          2       -6.000000e-01  Negative
# 7           31          3        5.000000e-01  Positive
# 8           16          1        0.000000e+00   Neutral
# 9           71          6        1.000000e-01  Positive
# 10          76          4        1.781250e-01  Positive
# 11         103          8        2.100000e-01  Positive
# 12          10          0        8.000000e-01  Positive
# 13          13          0        0.000000e+00   Neutral
# 14         110          8        4.928571e-01  Positive
# 15          17          0        6.000000e-01  Positive
# 16         641         56        3.578125e-01  Positive
# 17          59          6        2.500000e-01  Positive
# 18         361         24        1.700000e-01  Positive
# 19         269         20       -2.071429e-01  Negative
# 20          75          4        2.906250e-01  Positive
# 21         212         14        6.500000e-01  Positive
# 22         409         35        3.414773e-01  Positive
# 23         141         16       -3.700743e-17  Negative
# 24         860         69        4.388889e-02  Positive
# 25          11          1        3.000000e-01  Positive
# 26          30          2        6.500000e-01  Positive
# 27          45          2        2.500000e-01  Positive
# 28         496         34        2.569444e-01  Positive
# 29         189         12        1.497768e-01  Positive
# 30         401         36        5.606061e-02  Positive
# 31         100          8        1.500000e-01  Positive
# 32          44          4        1.500000e-01  Positive
# 33         928         32        6.000000e-02  Positive
# 34          11          0        8.000000e-01  Positive
# 35          43          3       -4.000000e-01  Negative
# 36          27          1        7.000000e-01  Positive
# 37         128          9        4.000000e-01  Positive
# 38         513         28        4.618056e-01  Positive
# 39          41          2        5.000000e-01  Positive
# 40          54          3        0.000000e+00   Neutral
# 41          22          1        0.000000e+00   Neutral
# 42          41          2        5.000000e-01  Positive
# 43         412         38        1.833333e-01  Positive
# 44          29          0        3.000000e-01  Positive
# 45           7          1        5.000000e-01  Positive
# 46         249         20        1.480519e-01  Positive
# 47          20          1        3.000000e-01  Positive
# 48          43          4        7.000000e-01  Positive

# %% [markdown]
# **Visualizations**

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(10,5))
count=[45,4,2]
senti=['Positive','Negative','Neutral']
plt.bar(senti,count,color='c');

# %%
# Joining the list into one string/text
text = ' '.join(data['review_body'])
text
# Out:
# 'excellent great quality wooden track better others tried perfect match various vintage thomas track already enough track fun get creative incorporating key piece track split loop bend card big pictured daughter loved liked price came rather shopping ton people around amazon best way shop buy break fast spun 15 minute end flew dont waste money made cheap plastic crack buy poi ball work lot better limited fund great item picture pop thru add detail 34painted34 picture dry repainted keep together use crazy glue pleased product child like showed shown someone old toy paint really liked little larger thought still fun nice huge balloon local grocery store fill small fee totally worth great deal advertised come w 15 servo expect spend 150 good servo immediately stock one break right away awesome thanks got item son play around closest relevance item like army trained camera rc bot thing awesome tested range got somewhere close 50 yard without issue getting control bit tricky first twenty minute get feel drone come fly ready sync controller definitely fan drone concern maybe little silent great buybr br disclaimer received product discount unbiased review birthday present grandson love got wrong product amazon vine unable provide good review received pair cute girl glove baseball ball instead expecting boy batting tee glove cute however made least 6 yr abovemore likely 89 yr old girlsbr br cant provide fair review able use product need expansion pack 35 want access player aid faction expansion base game alien frontier play much smoother adding faction expansion pack pigeonhole certain path victory awesome customer service cool little drone especially price got daughter plane trip liked zipper pouch attached marker however pouch fell girl loved coloring sticker would def buy girlfriend yoga gave set yoga joes new home yoga room saw impressed found little green army men like brother used play realized yoga almost exploded delight seen look face needle say gift huge hit absolutely brilliant like absoloutely hate doll dont pet like one im stoked really would liked see pet many wow toy home love well made advent calendar exception plastic thinner wow toy barn animal wont even stand due head weighing body uneven base toy disappointing love concept story read along everyday great would preferred quality would paid instead cheap 34knockoff34 rest toy line obvious weight toy sloppy paint job item 34wow toys34 bin part advent calendar v rest toy also lot overlap wow town advent calendar winter wonderland calendar make want look alternative year advent calendar option ton fun love great add collecton exactly described fit 7yr old well purchased lego help aid teaching sunday school class child loved best part helped child remember past lesson true lego brand seem worksnap togetherfit together better generic brand plus lego snob class would use real lego brand shunned generic brand wish lego little cheaper get pay would recommend quality purchase set ok good old bite meez puppet puppet thin little yorkie often bite hand right stuffing durable enough really play gift husband new pool receive color ordered one month use continuously mesh pulled away material inflatable side completely shredded longer use stored properly kept outside pool poorly made better going wm getting something clearance ended sending guy back didnt need ive bought one past loved product good box broken work well quality product style board charge multiple battery time safely battery cell count battery composition lipo nimhetc must individual cell voltage close equal battery connected time board connected charger read total individual cell voltage one battery may charge others degree total rate charge divided equally battery connected time close monitoring must using like high discharge batteies personally expeienced one lipo battery meltdown short non existant window opperunity prevent minimise colatteral damage process start read understand charging battery instruction grea ...

# %% [markdown]
# **Word Cloud for our reviews**

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
with open(r'positive-words.txt') as pw:
    positive_words = pw.read().split("\n")

# %%
positive_words = positive_words[35:]

# %%
with open('negative-words.txt') as nw:
    negative_words = nw.read().split("\n")

# %%
negative_words = negative_words[35:]

# %%
# Generate wordcloud
stopwords = STOPWORDS
stopwords.add('will')
wordcloud = WordCloud(width = 3000, height = 2000, background_color='black', max_words=100,colormap='Set2',stopwords=stopwords).generate(text)
# Plot
plot_cloud(wordcloud)

# %%
#tokenizing
from nltk import tokenize
sentences = tokenize.sent_tokenize(" ".join(data))
sentences[0:50]
# Out:
# ['marketplace customer_id review_id product_id product_parent product_title product_category star_rating helpful_votes total_votes vine verified_purchase review_headline review_body review_date word_count char_count stopwords sentiment_polarity sentiment']

# %% [markdown]
# **Emotion Mining - Sentiment Analysis**

# %%
from nltk import tokenize
sentences=tokenize.sent_tokenize(' '.join(data))
sentences
# Out:
# ['marketplace customer_id review_id product_id product_parent product_title product_category star_rating helpful_votes total_votes vine verified_purchase review_headline review_body review_date word_count char_count stopwords sentiment_polarity sentiment']

# %%
sent_df=pd.DataFrame(sentences,columns=['sentence'])
sent_df
# Out:
#                                             sentence
# 0  marketplace customer_id review_id product_id p...

# %%
# Emotion Lexicon - Affin
affin=pd.read_csv('Afinn.csv',sep=',',encoding='Latin-1')
affin
# Out:
#            word  value
# 0       abandon     -2
# 1     abandoned     -2
# 2      abandons     -2
# 3      abducted     -2
# 4     abduction     -2
# ...         ...    ...
# 2472      yucky     -2
# 2473      yummy      3
# 2474     zealot     -2
# 2475    zealots     -2
# 2476    zealous      2
#
# [2477 rows x 2 columns]

# %%
affinity_scores=affin.set_index('word')['value'].to_dict()
affinity_scores
# Out:
# {'abandon': -2,
#  'abandoned': -2,
#  'abandons': -2,
#  'abducted': -2,
#  'abduction': -2,
#  'abductions': -2,
#  'abhor': -3,
#  'abhorred': -3,
#  'abhorrent': -3,
#  'abhors': -3,
#  'abilities': 2,
#  'ability': 2,
#  'aboard': 1,
#  'absentee': -1,
#  'absentees': -1,
#  'absolve': 2,
#  'absolved': 2,
#  'absolves': 2,
#  'absolving': 2,
#  'absorbed': 1,
#  'abuse': -3,
#  'abused': -3,
#  'abuses': -3,
#  'abusive': -3,
#  'accept': 1,
#  'accepted': 1,
#  'accepting': 1,
#  'accepts': 1,
#  'accident': -2,
#  'accidental': -2,
#  'accidentally': -2,
#  'accidents': -2,
#  'accomplish': 2,
#  'accomplished': 2,
#  'accomplishes': 2,
#  'accusation': -2,
#  'accusations': -2,
#  'accuse': -2,
#  'accused': -2,
#  'accuses': -2,
#  'accusing': -2,
#  'ache': -2,
#  'achievable': 1,
#  'aching': -2,
#  'acquit': 2,
#  'acquits': 2,
#  'acquitted': 2,
#  'acquitting': 2,
#  'acrimonious': -3,
#  'active': 1,
#  'adequate': 1,
#  'admire': 3,
#  'admired': 3,
#  'admires': 3,
#  'admiring': 3,
#  'admit': -1,
#  'admits': -1,
#  'admitted': -1,
#  'admonish': -2,
#  'admonished': -2,
#  'adopt': 1,
#  'adopts': 1,
#  'adorable': 3,
#  'adore': 3,
#  'adored': 3,
#  'adores': 3,
#  'advanced': 1,
#  'advantage': 2,
#  'advantages': 2,
#  'adventure': 2,
#  'adventures': 2,
#  'adventurous': 2,
#  'affected': -1,
#  'affection': 3,
#  'affectionate': 3,
#  'afflicted': -1,
#  'affronted': -1,
#  'afraid': -2,
#  'aggravate': -2,
#  'aggravated': -2,
#  'aggravates': -2,
#  'aggravating': -2,
#  'aggression': -2,
#  'aggressions': -2,
#  'aggressive': -2,
#  'aghast': -2,
#  'agog': 2,
#  'agonise': -3,
#  'agonised': -3,
#  'agonises': -3,
#  'agonising': -3,
#  'agonize': -3,
#  'agonized': -3,
#  'agonizes': -3,
#  'agonizing': -3,
#  'agree': 1,
#  'agreeable': 2,
#  'agreed': 1,
#  'agreement': 1,
#  'agrees': 1,
#  'alarm': -2,
#  'alarmed': -2,
#  'alarmist': -2,
#  'alarmists': -2,
#  'alas': -1,
#  'alert': -1,
#  'alienation': -2,
#  'alive': 1,
#  'allergic': -2,
#  'allow': 1,
#  'alone': -2,
#  'amaze': 2,
#  'amazed': 2,
#  'amazes': 2,
#  'amazing': 4,
#  'ambitious': 2,
#  'ambivalent': -1,
#  'amuse': 3,
#  'amused': 3,
#  'amusement': 3,
#  'amusements': 3,
#  'anger': -3,
#  'angers': -3,
#  'angry': -3,
#  'anguish': -3,
#  'anguished': -3,
#  'animosity': -2,
#  'annoy': -2,
#  'annoyance': -2,
#  'annoyed': -2,
#  'annoying': -2,
#  'annoys': -2,
#  'antagonistic': -2,
#  'anti': -1,
#  'anticipation': 1,
#  'anxiety': -2,
#  'anxious': -2,
#  'apathetic': -3,
#  'apathy': -3,
#  'apeshit': -3,
#  'apocalyptic': -2,
#  'apologise': -1,
#  'apologised': -1,
#  'apologises': -1,
#  'apologising': -1,
#  'apologize': -1,
#  'apologized': -1,
#  'apologizes': -1,
#  'apologizing': -1,
#  'apology': -1,
#  'appalled': -2,
#  'appalling': -2,
#  'appease': 2,
#  'appeased': 2,
#  'appeases': 2,
#  'appeasing': 2,
#  'applaud': 2,
#  'applauded': 2,
#  'applauding': 2,
#  'applauds': 2,
#  'applause': 2,
#  'appreciate': 2,
#  'appreciated': 2,
#  'appreciates': 2,
#  'appreciating': 2,
#  'appreciation': 2,
#  'apprehensive': -2,
#  'approval': 2,
#  'approved': 2,
#  'approves': 2,
#  'ardent': 1,
#  'arrest': -2,
#  'arrested': -3,
#  'arrests': -2,
#  'arrogant': -2,
#  'ashame': -2,
#  'ashamed': -2,
#  'ass': -4,
#  'assassination': -3,
#  'assassinations': -3,
#  'asset': 2,
#  'assets': 2,
#  'assfucking': -4,
#  'asshole': -4,
#  'astonished': 2,
#  'astound': 3,
#  'astounded': 3,
#  'astounding': 3,
#  'astoundingly': 3,
#  'astounds': 3,
#  'attack': -1,
#  'attacked': -1,
#  'attacking': -1,
#  'attacks': -1,
#  'attract': 1,
#  'attracted': 1,
#  'attracting': 2,
#  'attraction': 2,
#  'attractions': 2,
#  'attracts': 1,
#  'audacious': 3,
#  'authority': 1,
#  'avert': -1,
#  'averted': -1,
#  'averts': -1,
#  'avid': 2,
#  'avoid': -1,
#  'avoided': -1,
#  'avoids': -1,
#  'await': -1,
#  'awaited': -1,
#  'awaits': -1,
#  'award': 3,
#  'awarded': 3,
#  'awards': 3,
#  'awesome': 4,
#  'awful': -3,
#  'awkward': -2,
#  'axe': -1,
#  'axed': -1,
#  'backed': 1,
#  'backing': 2,
#  'backs': 1,
#  'bad': -3,
#  'badass': -3,
#  'badly': -3,
#  'bailout': -2,
#  'bamboozle': -2,
#  'bamboozled': -2,
#  'bamboozles': -2,
#  'ban': -2,
#  'banish': -1,
#  'bankrupt': -3,
#  'bankster': -3,
#  'banned': -2,
#  'bargain': 2,
#  'barrier': -2,
#  'bastard': -5,
#  'bastards': -5,
#  'battle': -1,
#  'battles': -1,
#  'beaten': -2,
#  'beatific': 3,
#  'beating': -1,
#  'beauties': 3,
#  'beautiful': 3,
#  'beautifully': 3,
#  'beautify': 3,
#  'belittle': -2,
#  'belittled': -2,
#  'beloved': 3,
#  'benefit': 2,
#  'benefits': 2,
#  'benefitted': 2,
#  'benefitting': 2,
#  'bereave': -2,
#  'bereaved': -2,
#  'bereaves': -2,
#  'bereaving': -2,
#  'best': 3,
#  'betray': -3,
#  'betrayal': -3,
#  'betrayed': -3,
#  'betraying': -3,
#  'betrays': -3,
#  'better': 2,
#  'bias': -1,
#  'biased': -2,
#  'big': 1,
#  'bitch': -5,
#  'bitches': -5,
#  'bitter': -2,
#  'bitterly': -2,
#  'bizarre': -2,
#  'blah': -2,
#  'blame': -2,
#  'blamed': -2,
#  'blames': -2,
#  'blaming': -2,
#  'bless': 2,
#  'blesses': 2,
#  'blessing': 3,
#  'blind': -1,
#  'bliss': 3,
#  'blissful': 3,
#  'blithe': 2,
#  'block': -1,
#  'blockbuster': 3,
#  'blocked': -1,
#  'blocking': -1,
#  'blocks': -1,
#  'bloody': -3,
#  'blurry': -2,
#  'boastful': -2,
#  'bold': 2,
#  'boldly': 2,
#  'bomb': -1,
#  'boost': 1,
#  'boosted': 1,
#  'boosting': 1,
#  'boosts': 1,
#  'bore': -2,
#  'bored': -2,
#  'boring': -3,
#  'bother': -2,
#  'bothered': -2,
#  'bothers': -2,
#  'bothersome': -2,
#  'boycott': -2,
#  'boycotted': -2,
#  'boycotting': -2,
#  'boycotts': -2,
#  'brainwashing': -3,
#  'brave': 2,
#  'breakthrough': 3,
#  'breathtaking': 5,
#  'bribe': -3,
#  'bright': 1,
#  'brightest': 2,
#  'brightness': 1,
#  'brilliant': 4,
#  'brisk': 2,
#  'broke': -1,
#  'broken': -1,
#  'brooding': -2,
#  'bullied': -2,
#  'bullshit': -4,
#  'bully': -2,
#  'bullying': -2,
#  'bummer': -2,
#  'buoyant': 2,
#  'burden': -2,
#  'burdened': -2,
#  'burdening': -2,
#  'burdens': -2,
#  'calm': 2,
#  'calmed': 2,
#  'calming': 2,
#  'calms': 2,
#  "can't stand": -3,
#  'cancel': -1,
#  'cancelled': -1,
#  'cancelling': -1,
#  'cancels': -1,
#  'cancer': -1,
#  'capable': 1,
#  'captivated': 3,
#  'care': 2,
#  'carefree': 1,
#  'careful': 2,
#  'carefully': 2,
#  'careless': -2,
#  'cares': 2,
#  'cashing in': -2,
#  'casualty': -2,
#  'catastrophe': -3,
#  'catastrophic': -4,
#  'cautious': -1,
#  'celebrate': 3,
#  'celebrated': 3,
#  'celebrates': 3,
#  'celebrating': 3,
#  'censor': -2,
#  'censored': -2,
#  'censors': -2,
#  'certain': 1,
#  'chagrin': -2,
#  'chagrined': -2,
#  'challenge': -1,
#  'chance': 2,
#  'chances': 2,
#  'chaos': -2,
#  'chaotic': -2,
#  'charged': -3,
#  'charges': -2,
#  'charm': 3,
#  'charming': 3,
#  'charmless': -3,
#  'chastise': -3,
#  'chastised': -3,
#  'chastises': -3,
#  'chastising': -3,
#  'cheat': -3,
#  'cheated': -3,
#  'cheater': -3,
#  'cheaters': -3,
#  'cheats': -3,
#  'cheer': 2,
#  'cheered': 2,
#  'cheerful': 2,
#  'cheering': 2,
#  'cheerless': -2,
#  'cheers': 2,
#  'cheery': 3,
#  'cherish': 2,
#  'cherished': 2,
#  'cherishes': 2,
#  'cherishing': 2,
#  'chic': 2,
#  'childish': -2,
#  'chilling': -1,
#  'choke': -2,
#  'choked': -2,
#  'chokes': -2,
#  'choking': -2,
#  'clarifies': 2,
#  'clarity': 2,
#  'clash': -2,
#  'classy': 3,
#  'clean': 2,
#  'cleaner': 2,
#  'clear': 1,
#  'cleared': 1,
#  'clearly': 1,
#  'clears': 1,
#  'clever': 2,
#  'clouded': -1,
#  'clueless': -2,
#  'cock': -5,
#  'cocksucker': -5,
#  'cocksuckers': -5,
#  'cocky': -2,
#  'coerced': -2,
#  'collapse': -2,
#  'collapsed': -2,
#  'collapses': -2,
#  'collapsing': -2,
#  'collide': -1,
#  'collides': -1,
#  'colliding': -1,
#  'collision': -2,
#  'collisions': -2,
#  'colluding': -3,
#  'combat': -1,
#  'combats': -1,
#  'comedy': 1,
#  'comfort': 2,
#  'comfortable': 2,
#  'comforting': 2,
#  'comforts': 2,
#  'commend': 2,
#  'commended': 2,
#  'commit': 1,
#  'commitment': 2,
#  'commits': 1,
#  'committed': 1,
#  'committing': 1,
#  'compassionate': 2,
#  'compelled': 1,
#  'competent': 2,
#  'competitive': 2,
#  'complacent': -2,
#  'complain': -2,
#  'complained': -2,
#  'complains': -2,
#  'comprehensive': 2,
#  'conciliate': 2,
#  'conciliated': 2,
#  'conciliates': 2,
#  'conciliating': 2,
#  'condemn': -2,
#  'condemnation': -2,
#  'condemned': -2,
#  'condemns': -2,
#  'confidence': 2,
#  'confident': 2,
#  'conflict': -2,
#  'conflicting': -2,
#  'conflictive': -2,
#  'conflicts': -2,
#  'confuse': -2,
#  'confused': -2,
#  'confusing': -2,
#  'congrats': 2,
#  'congratulate': 2,
#  'congratulation': 2,
#  'congratulations': 2,
#  'consent': 2,
#  'consents': 2,
#  'consolable': 2,
#  'conspiracy': -3,
#  'constrained': -2,
#  'contagion': -2,
#  'contagions': -2,
#  'contagious': -1,
#  'contempt': -2,
#  'contemptuous': -2,
#  'contemptuously': -2,
#  'contend': -1,
#  'contender': -1,
#  'contending': -1,
#  'contentious': -2,
#  'contestable': -2,
#  'controversial': -2,
#  'controversially': -2,
#  'convince': 1,
#  'convinced': 1,
#  'convinces': 1,
#  'convivial': 2,
#  'cool': 1,
#  'cool stuff': 3,
#  'cornered': -2,
#  'corpse': -1,
#  'costly': -2,
#  'courage': 2,
#  'courageous': 2,
#  'courteous': 2,
#  'courtesy': 2,
#  'cover-up': -3,
#  'coward': -2,
#  'cowardly': -2,
#  'coziness': 2,
#  'cramp': -1,
#  'crap': -3,
#  'crash': -2,
#  'crazier': -2,
#  'craziest': -2,
#  'crazy': -2,
#  'creative': 2,
#  'crestfallen': -2,
#  'cried': -2,
#  'cries': -2,
#  'crime': -3,
#  'criminal': -3,
#  'criminals': -3,
#  'crisis': -3,
#  'critic': -2,
#  'criticism': -2,
#  'criticize': -2,
#  'criticized': -2,
#  'criticizes': -2,
#  'criticizing': -2,
#  'critics': -2,
#  'cruel': -3,
#  'cruelty': -3,
#  'crush': -1,
#  'crushed': -2,
#  'crushes': -1,
#  'crushing': -1,
#  'cry': -1,
#  'crying': -2,
#  'cunt': -5,
#  'curious': 1,
#  'curse': -1,
#  'cut': -1,
#  'cute': 2,
#  'cuts': -1,
#  'cutting': -1,
#  'cynic': -2,
#  'cynical': -2,
#  'cynicism': -2,
#  'damage': -3,
#  'damages': -3,
#  'damn': -4,
#  'damned': -4,
#  'damnit': -4,
#  'danger': -2,
#  'daredevil': 2,
#  'daring': 2,
#  'darkest': -2,
#  'darkness': -1,
#  'dauntless': 2,
#  'dead': -3,
#  'deadlock': -2,
#  'deafening': -1,
#  'dear': 2,
#  'dearly': 3,
#  'death': -2,
#  'debonair': 2,
#  'debt': -2,
#  'deceit': -3,
#  'deceitful': -3,
#  'deceive': -3,
#  'deceived': -3,
#  'deceives': -3,
#  'deceiving': -3,
#  'deception': -3,
#  'decisive': 1,
#  'dedicated': 2,
#  'defeated': -2,
#  'defect': -3,
#  'defects': -3,
#  'defender': 2,
#  'defenders': 2,
#  'defenseless': -2,
#  'defer': -1,
#  'deferring': -1,
#  'defiant': -1,
#  'deficit': -2,
#  'degrade': -2,
#  'degraded': -2,
#  'degrades': -2,
#  'dehumanize': -2,
#  'dehumanized': -2,
#  'dehumanizes': -2,
#  'dehumanizing': -2,
#  'deject': -2,
#  'dejected': -2,
#  'dejecting': -2,
#  'dejects': -2,
#  'delay': -1,
#  'delayed': -1,
#  'delight': 3,
#  'delighted': 3,
#  'delighting': 3,
#  'delights': 3,
#  'demand': -1,
#  'demanded': -1,
#  'demanding': -1,
#  'demands': -1,
#  'demonstration': -1,
#  'demoralized': -2,
#  'denied': -2,
#  'denier': -2,
#  'deniers': -2,
#  'denies': -2,
#  'denounce': -2,
#  'denounces': -2,
#  'deny': -2,
#  'denying': -2,
#  'depressed': -2,
#  'depressing': -2,
#  'derail': -2,
#  'derailed': -2,
#  'derails': -2,
#  'deride': -2,
#  'derided': -2,
#  'derides': -2,
#  'deriding': -2,
#  'derision': -2,
#  'desirable': 2,
#  'desire': 1,
#  'desired': 2,
#  'desirous': 2,
#  'despair': -3,
#  'despairing': -3,
#  'despairs': -3,
#  'desperate': -3,
#  'desperately': -3,
#  'despondent': -3,
#  'destroy': -3,
#  'destroyed': -3,
#  'destroying': -3,
#  'destroys': -3,
#  'destruction': -3,
#  'destructive': -3,
#  'detached': -1,
#  'detain': -2,
#  'detained': -2,
#  'detention': -2,
#  'determined': 2,
#  'devastate': -2,
#  'devastated': -2,
#  'devastating': -2,
#  'devoted': 3,
#  'diamond': 1,
#  'dick': -4,
#  'dickhead': -4,
#  'die': -3,
#  'died': -3,
#  'difficult': -1,
#  'diffident': -2,
#  'dilemma': -1,
#  'dipshit': -3,
#  'dire': -3,
#  'direful': -3,
#  'dirt': -2,
#  'dirtier': -2,
#  'dirtiest': -2,
#  'dirty': -2,
#  'disabling': -1,
#  'disadvantage': -2,
#  'disadvantaged': -2,
#  'disappear': -1,
#  'disappeared': -1,
#  'disappears': -1,
#  'disappoint': -2,
#  'disappointed': -2,
#  'disappointing': -2,
#  'disappointment': -2,
#  'disappointments': -2,
#  'disappoints': -2,
#  'disaster': -2,
#  'disasters': -2,
#  'disastrous': -3,
#  'disbelieve': -2,
#  'discard': -1,
#  'discarded': -1,
#  'discarding': -1,
#  'discards': -1,
#  'disconsolate': -2,
#  'disconsolation': -2,
#  'discontented': -2,
#  'discord': -2,
#  'discounted': -1,
#  'discouraged': -2,
#  'discredited': -2,
#  'disdain': -2,
#  'disgrace': -2,
#  'disgraced': -2,
#  'disguise': -1,
#  'disguised': -1,
#  'disguises': -1,
#  'disguising': -1,
#  'disgust': -3,
#  'disgusted': -3,
#  'disgusting': -3,
#  'disheartened': -2,
#  'dishonest': -2,
#  'disillusioned': -2,
#  'disinclined': -2,
#  'disjointed': -2,
#  'dislike': -2,
#  'dismal': -2,
#  'dismayed': -2,
#  'disorder': -2,
#  'disorganized': -2,
#  'disoriented': -2,
#  'disparage': -2,
#  'disparaged': -2,
#  'disparages': -2,
#  'disparaging': -2,
#  'displeased': -2,
#  'dispute': -2,
#  'disputed': -2,
#  'disputes': -2,
#  'disputing': -2,
#  'disqualified': -2,
#  'disquiet': -2,
#  'disregard': -2,
#  'disregarded': -2,
#  'disregarding': -2,
#  'disregards': -2,
#  'disrespect': -2,
#  'disrespected': -2,
#  'disruption': -2,
#  'disruptions': -2,
#  'disruptive': -2,
#  'dissatisfied': -2,
#  'distort': -2,
#  'distorted': -2,
#  'distorting': -2,
#  'distorts': -2,
#  'distract': -2,
#  'distracted': -2,
#  'distraction': -2,
#  'distracts': -2,
#  'distress': -2,
#  'distressed': -2,
#  'distresses': -2,
#  'distressing': -2,
#  'distrust': -3,
#  'distrustful': -3,
#  'disturb': -2,
#  'disturbed': -2,
#  'disturbing': -2,
#  'disturbs': -2,
#  'dithering': -2,
#  'dizzy': -1,
#  'dodging': -2,
#  'dodgy': -2,
#  'does not work': -3,
#  'dolorous': -2,
#  'dont like': -2,
#  'doom': -2,
#  'doomed': -2,
#  'doubt': -1,
#  'doubted': -1,
#  'doubtful': -1,
#  'doubting': -1,
#  'doubts': -1,
#  'douche': -3,
#  'douchebag': -3,
#  'downcast': -2,
#  'downhearted': -2,
#  'downside': -2,
#  'drag': -1,
#  'dragged': -1,
#  'drags': -1,
#  'drained': -2,
#  'dread': -2,
#  'dreaded': -2,
#  'dreadful': -3,
#  'dreading': -2,
#  'dream': 1,
#  'dreams': 1,
#  'dreary': -2,
#  'droopy': -2,
#  'drop': -1,
#  'drown': -2,
#  'drowned': -2,
#  'drowns': -2,
#  'drunk': -2,
#  'dubious': -2,
#  'dud': -2,
#  'dull': -2,
#  'dumb': -3,
#  'dumbass': -3,
#  'dump': -1,
#  'dumped': -2,
#  'dumps': -1,
#  'dupe': -2,
#  'duped': -2,
#  'dysfunction': -2,
#  'eager': 2,
#  'earnest': 2,
#  'ease': 2,
#  'easy': 1,
#  'ecstatic': 4,
#  'eerie': -2,
#  'eery': -2,
#  'effective': 2,
#  'effectively': 2,
#  'elated': 3,
#  'elation': 3,
#  'elegant': 2,
#  'elegantly': 2,
#  'embarrass': -2,
#  'embarrassed': -2,
#  'embarrasses': -2,
#  'embarrassing': -2,
#  'embarrassment': -2,
#  'embittered': -2,
#  'embrace': 1,
#  'emergency': -2,
#  'empathetic': 2,
#  'emptiness': -1,
#  'empty': -1,
#  'enchanted': 2,
#  'encourage': 2,
#  'encouraged': 2,
#  'encouragement': 2,
#  'encourages': 2,
#  'endorse': 2,
#  'endorsed': 2,
#  'endorsement': 2,
#  'endorses': 2,
#  'enemies': -2,
#  'enemy': -2,
#  'energetic': 2,
#  'engage': 1,
#  'engages': 1,
#  'engrossed': 1,
#  'enjoy': 2,
#  'enjoying': 2,
#  'enjoys': 2,
#  'enlighten': 2,
#  'enlightened': 2,
#  'enlightening': 2,
#  'enlightens': 2,
#  'ennui': -2,
#  'enrage': -2,
#  'enraged': -2,
#  'enrages': -2,
#  'enraging': -2,
#  'enrapture': 3,
#  'enslave': -2,
#  'enslaved': -2,
#  'enslaves': -2,
#  'ensure': 1,
#  'ensuring': 1,
#  'enterprising': 1,
#  'entertaining': 2,
#  'enthral': 3,
#  'enthusiastic': 3,
#  'entitled': 1,
#  'entrusted': 2,
#  'envies': -1,
#  'envious': -2,
#  'envy': -1,
#  'envying': -1,
#  'erroneous': -2,
#  'error': -2,
#  'errors': -2,
#  'escape': -1,
#  'escapes': -1,
#  'escaping': -1,
#  'esteemed': 2,
#  'ethical': 2,
#  'euphoria': 3,
#  'euphoric': 4,
#  'eviction': -1,
#  'evil': -3,
#  'exaggerate': -2,
#  'exaggerated': -2,
#  'exaggerates': -2,
#  'exaggerating': -2,
#  'exasperated': 2,
#  'excellence': 3,
#  'excellent': 3,
#  'excite': 3,
#  'excited': 3,
#  'excitement': 3,
#  'exciting': 3,
#  'exclude': -1,
#  'excluded': -2,
#  'exclusion': -1,
#  'exclusive': 2,
#  'excuse': -1,
#  'exempt': -1,
#  'exhausted': -2,
#  'exhilarated': 3,
#  'exhilarates': 3,
#  'exhilarating': 3,
#  'exonerate': 2,
#  'exonerated': 2,
#  'exonerates': 2,
#  'exonerating': 2,
#  'expand': 1,
#  'expands': 1,
#  'expel': -2,
#  'expelled': -2,
#  'expelling': -2,
#  'expels': -2,
#  'exploit': -2,
#  'exploited': -2,
#  'exploiting': -2,
#  'exploits': -2,
#  'exploration': 1,
#  'explorations': 1,
#  'expose': -1,
#  'exposed': -1,
#  'exposes': -1,
#  'exposing': -1,
#  'extend': 1,
#  'extends': 1,
#  'exuberant': 4,
#  'exultant': 3,
#  'exultantly': 3,
#  'fabulous': 4,
#  'fad': -2,
#  'fag': -3,
#  'faggot': -3,
#  'faggots': -3,
#  'fail': -2,
#  'failed': -2,
#  'failing': -2,
#  'fails': -2,
#  'failure': -2,
#  'failures': -2,
#  'fainthearted': -2,
#  'fair': 2,
#  'faith': 1,
#  'faithful': 3,
#  'fake': -3,
#  'fakes': -3,
#  'faking': -3,
#  'fallen': -2,
#  'falling': -1,
#  'falsified': -3,
#  'falsify': -3,
#  'fame': 1,
#  'fan': 3,
#  'fantastic': 4,
#  'farce': -1,
#  'fascinate': 3,
#  'fascinated': 3,
#  'fascinates': 3,
#  'fascinating': 3,
#  'fascist': -2,
#  'fascists': -2,
#  'fatalities': -3,
#  'fatality': -3,
#  'fatigue': -2,
#  'fatigued': -2,
#  'fatigues': -2,
#  'fatiguing': -2,
#  'favor': 2,
#  'favored': 2,
#  'favorite': 2,
#  'favorited': 2,
#  'favorites': 2,
#  'favors': 2,
#  'fear': -2,
#  'fearful': -2,
#  'fearing': -2,
#  'fearless': 2,
#  'fearsome': -2,
#  'fed up': -3,
#  'feeble': -2,
#  'feeling': 1,
#  'felonies': -3,
#  'felony': -3,
#  'fervent': 2,
#  'fervid': 2,
#  'festive': 2,
#  'fiasco': -3,
#  'fidgety': -2,
#  'fight': -1,
#  'fine': 2,
#  'fire': -2,
#  'fired': -2,
#  'firing': -2,
#  'fit': 1,
#  'fitness': 1,
#  'flagship': 2,
#  'flees': -1,
#  'flop': -2,
#  'flops': -2,
#  'flu': -2,
#  ...}

# %%
# Custom function: score each word in a sentence in lemmatised form, but calculate the score for the whole original sentence
nlp=spacy.load('en_core_web_sm')
sentiment_lexicon=affinity_scores

def calculate_sentiment(text:str=None):
    sent_score=0
    if text:
        sentence=nlp(text)
        for word in sentence:
            sent_score+=sentiment_lexicon.get(word.lemma_,0)
    return sent_score

# %%
# manual testing
calculate_sentiment(text='good service')
# Out:
# 3

# %%
# Calculating sentiment value for each sentence
sent_df['sentiment_value']=sent_df['sentence'].apply(calculate_sentiment)
sent_df['sentiment_value']
# Out:
# 0    0
# Name: sentiment_value, dtype: int64

# %%
# how many words are there in a sentence?
sent_df['word_count']=sent_df['sentence'].str.split().apply(len)
sent_df['word_count']
# Out:
# 0    20
# Name: word_count, dtype: int64

# %%
sent_df.sort_values(by='sentiment_value')
# Out:
#                                             sentence  sentiment_value  \
# 0  marketplace customer_id review_id product_id p...                0
#
#    word_count
# 0          20

# %%
# Sentiment score of the whole review
sent_df['sentiment_value'].describe()
# Out:
# count    1.0
# mean     0.0
# std      NaN
# min      0.0
# 25%      0.0
# 50%      0.0
# 75%      0.0
# max      0.0
# Name: sentiment_value, dtype: float64

# %%
# negative sentiment score of the whole review
sent_df[sent_df['sentiment_value']<=0]
# Out:
#                                             sentence  sentiment_value  \
# 0  marketplace customer_id review_id product_id p...                0
#
#    word_count
# 0          20

# %%
# positive sentiment score of the whole review
sent_df[sent_df['sentiment_value']>0]
# Out:
# Empty DataFrame
# Columns: [sentence, sentiment_value, word_count]
# Index: []

# %%
# Adding index cloumn
sent_df['index']=range(0,len(sent_df))
sent_df
# Out:
#                                             sentence  sentiment_value  \
# 0  marketplace customer_id review_id product_id p...                0
#
#    word_count  index
# 0          20      0
